# %%
# Tratamiento de datos
# ------------------------------------------------------------------------------
import numpy as np
import pandas as pd
import statsmodels.api as sm

# Gráficos
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt

# Preprocesado y modelado
# ------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.model_selection import GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.pipeline import Pipeline


# Configuración warnings
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('once')

# %% [markdown]
# # Laboratory practice 2.5: Decision Trees and Random Forest
#
# Given the following dataset:
#
# The Carseats dataset, originally from the R package ISLR and accessible in Python through statsmodels.datasets.get_rdataset, contains information on the sale of child seats in 400 different stores. For each of the 400 stores, 11 variables have been recorded. The aim is to generate a classification model that can **predict whether a store has high sales (Sales > 8) or low sales (Sales <= 8) based on all available variables**.

# %%
carseats = sm.datasets.get_rdataset("Carseats", "ISLR")
df = carseats.data
print(carseats.__doc__)
# Out:
# .. container::
#
#    ======== ===============
#    Carseats R Documentation
#    ======== ===============
#
#    .. rubric:: Sales of Child Car Seats
#       :name: sales-of-child-car-seats
#
#    .. rubric:: Description
#       :name: description
#
#    A simulated data set containing sales of child car seats at 400
#    different stores.
#
#    .. rubric:: Usage
#       :name: usage
#
#    ::
#
#       Carseats
#
#    .. rubric:: Format
#       :name: format
#
#    A data frame with 400 observations on the following 11 variables.
#
#    ``Sales``
#       Unit sales (in thousands) at each location
#
#    ``CompPrice``
#       Price charged by competitor at each location
#
#    ``Income``
#       Community income level (in thousands of dollars)
#
#    ``Advertising``
#       Local advertising budget for company at each location (in
#       thousands of dollars)
#
#    ``Population``
#       Population size in region (in thousands)
#
#    ``Price``
# ...

# %% [markdown]
# #### Exercise 1: Prepare the data
#
# 1.1 Encode the target variable according to description
#
# 1.2 Separate into train and test

# %% [markdown]
# #### Exercise 2: Decision Trees
#
# 2.1 Train a model using GridSearchCV by applying the preprocessing of your choice. Create a param_grid for the search of two hyperparameters. Explain the whole process (why you choose those hyperparameters, why you do those transformations,...)
#
# 2.2 Graph the tree and explain it
#
# 2.3 Is there any overfit in your tree? Why or why not? If yes, how can you avoid it?
#
# 2.4 What are the most important variables?
#
# 2.5 Graph the ROC curve
#
# #### Exercise 3: RandomForest
#
# 3.1 Train a model using GridSearchCV by applying the preprocessing of your choice. Create a param_grid for the search of two hyperparameters. Explain the whole process (why you choose those hyperparameters, why you do those transformations,...)
#
# 3.2 What are the most important variables?
#
# 3.3 Do you see any differences with respect to the Decision Trees model?
#
# 3.4 Make a comparison between the two models:
#
#     - plot the ROC curve of the two models on the same graph.
#     - Observe the distribution of the predictions of both models.
#
# #### Exercise 4: Optional
#
# Program a simple random forest using Decision Trees module.
